# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %%bash
# nvidia-smi

# %%
# %%bash
# # PindaPindahh ke direktori utama Colab
# cd /content
#
# # Install Paddle GPU
# python -m pip install paddlepaddle-gpu
#
# # Clone repo PaddleOCR jika belum ada, atau masuk jika sudah ada
# if [ ! -d "PaddleOCR" ]; then
#   git clone https://github.com/PaddlePaddle/PaddleOCR.git
# fi
#
# cd PaddleOCR
# # Install dependencies
# pip install -r requirements.txt

# %%
# %%bash
# # Copy file script dari Drive ke Colab
# # cp /content/drive/MyDrive/Projek_OCR/converter_coco.py /content/
#
# # Jalankan converternya
# # (Asumsinya script converter Anda otomatis membuat folder paddle_dataset)
# python drive/MyDrive/colab_notebooks/ocr/converter_coco.py

# %%
# %%bash
#
# python -m paddle.distributed.launch /content/PaddleOCR/tools/train.py -c /content/drive/MyDrive/colab_notebooks/ocr/ocr_finetune.yml

# %% [markdown]
# ### Mengekstrak File `.rar`
#
# Untuk mengekstrak file `.rar`, Anda perlu menginstal paket `unrar-free` terlebih dahulu, lalu gunakan perintah `unrar`.

# %%
# %%bash
# # Instal unrar-free
# # apt-get update
# # apt-get install unrar-free
#
# # Contoh cara mengekstrak file .rar
# # Ganti 'nama_file_anda.rar' dengan nama file RAR Anda yang sebenarnya
# # Ganti 'folder_tujuan/' dengan direktori tempat Anda ingin mengekstrak file
# # unrar e nama_file_anda.rar folder_tujuan/
#
# # Misalnya, jika file rar ada di Drive dan ingin diekstrak ke /content/data:
# unrar x /content/drive/MyDrive/colab_notebooks/ocr/dataset.rar /content/drive/MyDrive/colab_notebooks/ocr/dataset/
